# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np
import thinkstats2
import thinkplot
import matplotlib
import pandas as pd

# %%
df = pd.read_csv('Fielding.csv')

# %%
yearof2006 = df.E[df.yearID ==2006].dropna()
yearof2007 = df.E[df.yearID == 2007].dropna()
yearof2008= df.E[df.yearID == 2008].dropna()
yearof2009= df.E[df.yearID == 2009].dropna()
yearof2010= df.E[df.yearID == 2010].dropna()

# %%
yearof2006.describe()
# Out:
# count    1756.000000
# mean        1.746583
# std         3.522838
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        28.000000
# Name: E, dtype: float64

# %%
yearof2007.describe()
# Out:
# count    1782.000000
# mean        1.677890
# std         3.396427
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        26.000000
# Name: E, dtype: float64

# %%
yearof2008.describe()
# Out:
# count    1776.000000
# mean        1.669482
# std         3.190919
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        34.000000
# Name: E, dtype: float64

# %%
yearof2009.describe()
# Out:
# count    1763.000000
# mean        1.620533
# std         3.049640
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        23.000000
# Name: E, dtype: float64

# %%
yearof2010.describe()
# Out:
# count    1751.000000
# mean        1.730440
# std         3.319791
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        34.000000
# Name: E, dtype: float64

# %%
yearsAfter2000 = df[df.yearID >= 2000]
yearsAfter2000.E.dropna()
yearsAfter2000.describe()
# Out:
#              yearID         stint             G            GS       InnOuts  \
# count  30349.000000  30349.000000  30349.000000  30345.000000  30345.000000
# mean    2008.172724      1.087054     35.247751     24.489801    655.797133
# std        4.933319      0.298054     39.712970     39.280111   1027.030280
# min     2000.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2004.000000      1.000000      6.000000      0.000000     54.000000
# 50%     2008.000000      1.000000     20.000000      6.000000    192.000000
# 75%     2012.000000      1.000000     50.000000     30.000000    644.000000
# max     2016.000000      4.000000    162.000000    162.000000   4388.000000
#
#                  PO             A             E            DP           PB  \
# count  30349.000000  30349.000000  30349.000000  30349.000000  1949.000000
# mean      72.876668     27.516096      1.704274      6.780388     2.847614
# ...

# %%
histAfter2000 = thinkstats2.Hist(yearsAfter2000.E)
thinkplot.Hist(histAfter2000)
thinkplot.Show(xlabel='# Error in after 2000', ylabel='Frequency',title='Histogram',color ='red')


pmfAfter2000 = thinkstats2.Pmf(yearsAfter2000.E)
thinkplot.Pmf(pmfAfter2000)
thinkplot.Show(xlabel='# error in after 2000', ylabel='Probability',title='PMF')



cdfAfter2000 = thinkstats2.Cdf(yearsAfter2000.E,label='# Players')
thinkplot.Cdf(cdfAfter2000)
thinkplot.Show(xlabel='# Error in after 2000', ylabel='CDF', loc='upper left',title='CDF')

# %%
histyearof2006 = thinkstats2.Hist(yearof2006)
thinkplot.Hist(histyearof2006)
thinkplot.Show(xlabel='# Error in 2006', ylabel='Frequency',title='Histogram',color ='red')


pmfyearof2006 = thinkstats2.Pmf(yearof2006)
thinkplot.Pmf(pmfyearof2006)
thinkplot.Show(xlabel='# error in 2006', ylabel='Probability',title='PMF')



cdfyearof2006 = thinkstats2.Cdf(yearof2006,label='# Players')
thinkplot.Cdf(cdfyearof2006)
thinkplot.Show(xlabel='# Error in 2006', ylabel='CDF', loc='upper left',title='CDF')

# %%
histyearof2007 = thinkstats2.Hist(yearof2007)
thinkplot.Hist(histyearof2007)
thinkplot.Show(xlabel='# Error in 2007', ylabel='Frequency',title='Histogram',color ='red')


pmfyearof2007 = thinkstats2.Pmf(yearof2007)
thinkplot.Pmf(pmfyearof2007)
thinkplot.Show(xlabel='# error in 2007', ylabel='Probability',title='PMF')



cdfyearof2007 = thinkstats2.Cdf(yearof2007,label='# Players')
thinkplot.Cdf(cdfyearof2007)
thinkplot.Show(xlabel='# Error in 2007', ylabel='CDF', loc='upper left',title='CDF')

# %%
histyearof2008 = thinkstats2.Hist(yearof2008)
thinkplot.Hist(histyearof2008)
thinkplot.Show(xlabel='# Error in 2008', ylabel='Frequency',title='Histogram',color ='red')


pmfyearof2008 = thinkstats2.Pmf(yearof2008)
thinkplot.Pmf(pmfyearof2008)
thinkplot.Show(xlabel='# error in 2008', ylabel='Probability',title='PMF')



cdfyearof2008 = thinkstats2.Cdf(yearof2008,label='# Players')
thinkplot.Cdf(cdfyearof2008)
thinkplot.Show(xlabel='# Error in 2008', ylabel='CDF', loc='upper left',title='CDF')

# %%
histyearof2009 = thinkstats2.Hist(yearof2009)
thinkplot.Hist(histyearof2009)
thinkplot.Show(xlabel='# Error in 2009', ylabel='Frequency',title='Histogram',color ='red')


pmfyearof2009 = thinkstats2.Pmf(yearof2009)
thinkplot.Pmf(pmfyearof2009)
thinkplot.Show(xlabel='# error in 2009', ylabel='Probability',title='PMF')



cdfyearof2009 = thinkstats2.Cdf(yearof2009,label='# Players')
thinkplot.Cdf(cdfyearof2009)
thinkplot.Show(xlabel='# Error in 2009', ylabel='CDF', loc='upper left',title='CDF')

# %%
histyearof2010 = thinkstats2.Hist(yearof2010)
thinkplot.Hist(histyearof2010)
thinkplot.Show(xlabel='# Error in 2010', ylabel='Frequency',title='Histogram',color ='red')


pmfyearof2010 = thinkstats2.Pmf(yearof2010)
thinkplot.Pmf(pmfyearof2010)
thinkplot.Show(xlabel='# error in 2010', ylabel='Probability',title='PMF')



cdfyearof2010 = thinkstats2.Cdf(yearof2010,label='# Players')
thinkplot.Cdf(cdfyearof2010)
thinkplot.Show(xlabel='# Error in 2010', ylabel='CDF', loc='upper left',title='CDF')

# %%
histt2009 = thinkstats2.Hist(yearof2009,label='Error in 2009')
histt2009 = thinkstats2.Hist(yearof2010,label='Error in 2010')

width = 0.45
thinkplot.PrePlot(2)
thinkplot.Hist(histt2009, align='right', width=width,color='red')
thinkplot.Hist(histt2009, align='left', width=width)
thinkplot.Show(xlabel='# error in 2009 - # error 2010', ylabel='Frequency',title='Histogram',loc='upper right')


pmff2009 = thinkstats2.Pmf(yearof2009,label='in 2009')
thinkplot.Pmf(pmff2009,color='red')
pmff2010 = thinkstats2.Pmf(yearof2010,label='in 2010')
thinkplot.Pmf(pmff2010)
width = 0.45
thinkplot.PrePlot(2)
thinkplot.Show(xlabel='# error in 2009 - # error in 2010', ylabel='Probability',title='PMF')


cdff2009 = thinkstats2.Cdf(yearof2009,label='in 2009')
thinkplot.Cdf(cdff2009,color='red')
cdff2010 = thinkstats2.Cdf(yearof2010,label='in 2010')
thinkplot.Cdf(cdff2010)
width = 0.45
thinkplot.PrePlot(2)
thinkplot.Show(xlabel='# error in 2009 - # error in 2010', ylabel='CDF')

# %%
difafter = yearsAfter2000.E.diff()
cdf = thinkstats2.Cdf(difafter, label='actual')

thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='xxxx)', ylabel='CDF')

# %%
def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    meanx, varx = thinkstats2.MeanVar(xs)
    meany, vary = thinkstats2.MeanVar(ys)

    corr = Cov(xs, ys, meanx, meany) / np.sqrt(varx * vary)
    return corr

# %%
cleaned = df.dropna(subset=['yearID', 'E'])
cleaned
# Out:
#          playerID  yearID  stint teamID lgID POS    G     GS  InnOuts   PO  \
# 0       abercda01    1871      1    TRO  NaN  SS    1    NaN      NaN    1
# 1        addybo01    1871      1    RC1  NaN  2B   22    NaN      NaN   67
# 2        addybo01    1871      1    RC1  NaN  SS    3    NaN      NaN    8
# 3       allisar01    1871      1    CL1  NaN  2B    2    NaN      NaN    1
# 4       allisar01    1871      1    CL1  NaN  OF   29    NaN      NaN   51
# 5       allisdo01    1871      1    WS3  NaN   C   27    NaN      NaN   68
# 6       ansonca01    1871      1    RC1  NaN  1B    1    NaN      NaN    7
# 7       ansonca01    1871      1    RC1  NaN  2B    2    NaN      NaN    3
# 8       ansonca01    1871      1    RC1  NaN  3B   20    NaN      NaN   38
# 9       ansonca01    1871      1    RC1  NaN   C    5    NaN      NaN   10
# 10      ansonca01    1871      1    RC1  NaN  OF    1    NaN      NaN    0
# ...

# %%
def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)

    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov

# %%
heights, weights = cleaned.yearID, cleaned.E
Cov(heights, weights)
# Out:
# -101.42685299863159

# %%
class HypothesisTest(object):

    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)

    def PValue(self, iters=1000):
        self.test_stats = [self.TestStatistic(self.RunModel()) 
                           for _ in range(iters)]

        count = sum(1 for x in self.test_stats if x >= self.actual)
        return count / iters

    def TestStatistic(self, data):
        raise UnimplementedMethodException()

    def MakeModel(self):
        pass

    def RunModel(self):
        raise UnimplementedMethodException()

# %%
class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data
